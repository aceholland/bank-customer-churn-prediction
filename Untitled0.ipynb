# %% [markdown]
# <a href="https://colab.research.google.com/github/aceholland/bank-customer-churn-prediction/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %%
import kagglehub
import os

path = kagglehub.dataset_download("gauravtopre/bank-customer-churn-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'bank-customer-churn-dataset' dataset.
# Path to dataset files: /kaggle/input/bank-customer-churn-dataset

# %%
csv_files = glob.glob(os.path.join(path, '**', '*.csv'), recursive=True)

if not csv_files:
    raise FileNotFoundError(f"No CSV files found in the dataset directory or its subdirectories: {path}")

# Prioritize finding 'Bank Customer Churn Prediction.csv' (note the space in the filename)
found_target_csv = [f for f in csv_files if 'Bank Customer Churn Prediction.csv' in os.path.basename(f)]

if found_target_csv:
    file_path = found_target_csv[0]
else:
    # Fallback to the first CSV found if the specific one isn't present
    file_path = csv_files[0]
    print(f"Warning: 'Bank Customer Churn Prediction.csv' not found. Loading '{os.path.basename(file_path)}' instead.")

data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
cors = data.corr(numeric_only=True)
sns.heatmap(cors)
# Out:
# <Axes: >

# %%
sns.boxplot(x="churn", y="age", data=data)
plt.show()

# %%
sns.boxplot(x="churn", y="balance", data=data)
plt.show()

# %%
sns.boxplot(x="churn", y="credit_score", data=data)
plt.show()

# %%
plt.scatter(data['balance'], data['estimated_salary'])

# %%
#encodes male, female to binary , for eg male =1, female=0
#M   F   Trans
#1   0     0
#0   1     0
#0   0     1

# %%
from sklearn.preprocessing import LabelEncoder #converts our categorical data male and female to binary
encoder=LabelEncoder()
data['encoded']=encoder.fit_transform(data["gender"])
data[['churn', 'encoded']].head()
# Out:
#    churn  encoded
# 0      1        0
# 1      0        0
# 2      1        0
# 3      0        0
# 4      0        0

# %%
data['encoded'].value_counts()
# Out:
# encoded
# 1    5457
# 0    4543
# Name: count, dtype: int64

# %%
m_values=5457
f_values=4543
m_churn, f_churn=0,0
for i in range(0, len(data)):
  if (data['churn'][i]==1 and data['encoded'][i]==1):
    m_churn+=1
  elif (data['churn'][i]==1 and data['encoded'][i]==0):
    f_churn+=1

# %%
x=[m_churn, f_churn]
print(x)
# Out:
# [898, 1139]

# %%
plt.bar(['m', 'f'], x)
plt.xlabel('Gender')
plt.ylabel('Number of Churns')
plt.title('Churn by Gender')
plt.show()

# %%
y=data['churn']
x=data[['age', 'credit_score', 'encoded', 'tenure', 'balance', 'products_number', 'credit_card', 'active_member', 'estimated_salary']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_tr, x_ts, y_tr, y_ts=train_test_split(x,y, test_size=0.2)
scaling = StandardScaler()
scaling.fit(x_tr)
# Out:
# StandardScaler()

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_tr, y_tr)
model.score(x_ts, y_ts)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.796

# %%
model.coef_
#tells the weight depenancy on each feature
# Out:
# array([[ 4.64819546e-02, -4.53502448e-03, -3.00576034e-02,
#         -7.73459110e-02,  3.76844440e-06, -1.99833106e-02,
#         -7.16952757e-03, -4.67040503e-02, -1.27869378e-06]])

# %%
#puuting hyperparameter for increasing accuracy
from sklearn.pipeline import make_pipeline
test_score=[] #list stores value for every each individual lambda
for lam in np.arange(0.01, 100, 0.1):
  pipe = make_pipeline(StandardScaler(), LogisticRegression(C=1/lam))
  pipe.fit(x_tr, y_tr)
  scores=pipe.score(x_ts, y_ts)
  test_score.append(scores)
#lam = lambda which is the hyperparameters
# we take lamda from 0.1 to 100 and we check the value for each to find out the better one

# %%
plt.plot(test_score)

# %%
np.argmax(test_score)
# Out:
# np.int64(33)

# %%
l_best=0.01*33*0.1
print(l_best)
# Out:
# 0.033

# %%
from sklearn.linear_model import LogisticRegression
model=make_pipeline(StandardScaler(), LogisticRegression(C=1/l_best))
model.fit(x_tr, y_tr)
model.score(x_ts, y_ts)
# Out:
# 0.8155
